# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
data = pd.read_csv("C:\\Users\\Enes Jashari\\Desktop\RS1.csv")

# Use only one feature
open_prices = data['Open']

# Dependent variable Y
close_prices = data['Close']

# Split the data into training/testing sets
open_prices_train = np.array(open_prices[:880]).reshape((-1, 1)) #we take the first 450 elements
open_prices_test = np.array(open_prices[880:]).reshape((-1, 1))  #we take elements after 450 index

# Split the targets into training/testing sets
close_prices_train = close_prices[:880]   #we take the first 450 elements
close_prices_test = close_prices[880:]    #we take elements after 450 index 

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(open_prices_train, close_prices_train)

# Make predictions using the testing set
close_prices_pred = regr.predict(open_prices_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(close_prices_test, close_prices_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(close_prices_test, close_prices_pred))

# Plot outputs
plt.scatter(open_prices_test, close_prices_test, color="black")
plt.plot(open_prices_test, close_prices_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients:
#  [0.99574587]
# Mean squared error: 249.13
# Coefficient of determination: 0.99
